# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.bar([1,2,3,4],[20,10,50,30])
plt.bar([1,2,3,4],[20,10,50,30])plt.bar([1,2,3,4],[20,10,50,30])plt.show()

# %%
plt.bar([1,2,3,4],[20,10,50,30],width=0.3)
plt.legend("Shop1")
plt.show()

# %%
plt.bar([1,2,3,4],[40,20,30,20],width=0.3)
plt.legend("Shop2")
plt.show()

# %%
plt.bar([1,2,3,4],[20,10,50,30],width=0.5)
plt.bar([1,2,3,4],[40,20,30,20],width=0.3)
plt.legend(["Shop1","Shop2"],loc="upper right")
plt.show()

# %%
plt.bar([1,2,3,4],[20,10,50,30],width=0.3,color="y")
plt.bar([1.2,2.2,3.2,4.2],[40,20,30,20],width=0.3,color="r")
plt.legend(["Shop1","Shop2"],loc="upper right")
plt.show()

# %% [markdown]
# ### Histogram

# %%
# for checking the distribution

# %%
vals = [5,7,3,8,6,2,9,5,6,3,9,2,5,4,3,4,9,5,2,3,6,8]
plt.hist(vals)
plt.show()
